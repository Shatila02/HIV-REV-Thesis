# %%
import os
import shutil

def convert_codon_file_to_text(input_directory, output_directory):
    # Create the output directory if it doesn't exist
    os.makedirs(output_directory, exist_ok=True)

    # Get the list of directories in the input directory
    directories = [name for name in os.listdir(input_directory) if os.path.isdir(os.path.join(input_directory, name))]

    # Iterate over each directory
    for directory in directories:
        # Get the files in the current directory
        files = os.listdir(os.path.join(input_directory, directory))

        # Find the "codon" file, regardless of the extension
        codon_file = next((file for file in files if file.startswith("codon")), None)

        if codon_file:
            # Get the full path of the "codon" file
            codon_file_path = os.path.join(input_directory, directory, codon_file)

            # Create the output file path in the output directory
            output_file_path = os.path.join(output_directory, f"{directory}.txt")

            # Copy the contents of the "codon" file to the output file
            with open(codon_file_path, "r") as input_file, open(output_file_path, "w") as output_file:
                output_file.write(input_file.read())

            print(f"Converted {codon_file_path} to {output_file_path}")

# Specify the input directory path where the directories with "codon" files are located
input_directory_path = 'G:\\Projects\\HIV_updated\\snap_outputs\\2020'  # Replace with the actual path to the parent directory

# Specify the output directory path where the converted text files will be saved
output_directory_path = 'G:\\Projects\\HIV_updated\\snap_outputs\\2020\\codons'  # Replace with the actual path to the output directory

# Call the function to convert the "codon" files to text files
convert_codon_file_to_text(input_directory_path, output_directory_path)
# Out:
# Converted G:\Projects\HIV_updated\snap_outputs\2021\0102\codons.8240 to G:\Projects\HIV_updated\snap_outputs\2021\codons\0102.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\0102A\codons.3808 to G:\Projects\HIV_updated\snap_outputs\2021\codons\0102A.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\0107\codons.14624 to G:\Projects\HIV_updated\snap_outputs\2021\codons\0107.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\0108\codons.9416 to G:\Projects\HIV_updated\snap_outputs\2021\codons\0108.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\01A\codons.12684 to G:\Projects\HIV_updated\snap_outputs\2021\codons\01A.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\01ADF\codons.13844 to G:\Projects\HIV_updated\snap_outputs\2021\codons\01ADF.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\01AF\codons.1144 to G:\Projects\HIV_updated\snap_outputs\2021\codons\01AF.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\01AG\codons.15220 to G:\Projects\HIV_updated\snap_outputs\2021\codons\01AG.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\01B\codons.15072 to G:\Projects\HIV_updated\snap_outputs\2021\codons\01B.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\01BC\codons.10424 to G:\Projects\HIV_updated\snap_outputs\2021\codons\01BC.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\01C\codons.14340 to G:\Projects\HIV_updated\snap_outputs\2021\codons\01C.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\01FG\codons.13972 to G:\Projects\HIV_updated\snap_outputs\2021\codons\01FG.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\0206\codons.16652 to G:\Projects\HIV_updated\snap_outputs\2021\codons\0206.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\0209\codons.10792 to G:\Projects\HIV_updated\snap_outputs\2021\codons\0209.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\0213\codons.14444 to G:\Projects\HIV_updated\snap_outputs\2021\codons\0213.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\0222\codons.14960 to G:\Projects\HIV_updated\snap_outputs\2021\codons\0222.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\0225\codons.12312 to G:\Projects\HIV_updated\snap_outputs\2021\codons\0225.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\0263\codons.10228 to G:\Projects\HIV_updated\snap_outputs\2021\codons\0263.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\02A\codons.1836 to G:\Projects\HIV_updated\snap_outputs\2021\codons\02A.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\02AF\codons.11988 to G:\Projects\HIV_updated\snap_outputs\2021\codons\02AF.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\02AG\codons.12380 to G:\Projects\HIV_updated\snap_outputs\2021\codons\02AG.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\02B\codons.14800 to G:\Projects\HIV_updated\snap_outputs\2021\codons\02B.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\02BF\codons.1196 to G:\Projects\HIV_updated\snap_outputs\2021\codons\02BF.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\02BG\codons.16556 to G:\Projects\HIV_updated\snap_outputs\2021\codons\02BG.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\02C\codons.16464 to G:\Projects\HIV_updated\snap_outputs\2021\codons\02C.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\02D\codons.16260 to G:\Projects\HIV_updated\snap_outputs\2021\codons\02D.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\02F\codons.12488 to G:\Projects\HIV_updated\snap_outputs\2021\codons\02F.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\02FG\codons.3036 to G:\Projects\HIV_updated\snap_outputs\2021\codons\02FG.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\02G\codons.9912 to G:\Projects\HIV_updated\snap_outputs\2021\codons\02G.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\02GK\codons.8560 to G:\Projects\HIV_updated\snap_outputs\2021\codons\02GK.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\02H\codons.16616 to G:\Projects\HIV_updated\snap_outputs\2021\codons\02H.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\06A\codons.5788 to G:\Projects\HIV_updated\snap_outputs\2021\codons\06A.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\06B\codons.9508 to G:\Projects\HIV_updated\snap_outputs\2021\codons\06B.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\07B\codons.2312 to G:\Projects\HIV_updated\snap_outputs\2021\codons\07B.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\14F\codons.6796 to G:\Projects\HIV_updated\snap_outputs\2021\codons\14F.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\32A\codons.6300 to G:\Projects\HIV_updated\snap_outputs\2021\codons\32A.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\32G\codons.12948 to G:\Projects\HIV_updated\snap_outputs\2021\codons\32G.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\50B\codons.13672 to G:\Projects\HIV_updated\snap_outputs\2021\codons\50B.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\A\codons.14260 to G:\Projects\HIV_updated\snap_outputs\2021\codons\A.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\AB\codons.11016 to G:\Projects\HIV_updated\snap_outputs\2021\codons\AB.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\ABD\codons.9188 to G:\Projects\HIV_updated\snap_outputs\2021\codons\ABD.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\AC\codons.13284 to G:\Projects\HIV_updated\snap_outputs\2021\codons\AC.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\ACD\codons.17208 to G:\Projects\HIV_updated\snap_outputs\2021\codons\ACD.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\ACG\codons.13824 to G:\Projects\HIV_updated\snap_outputs\2021\codons\ACG.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\AD\codons.13424 to G:\Projects\HIV_updated\snap_outputs\2021\codons\AD.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\ADG\codons.11724 to G:\Projects\HIV_updated\snap_outputs\2021\codons\ADG.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\AE\codons.16188 to G:\Projects\HIV_updated\snap_outputs\2021\codons\AE.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\AF\codons.17364 to G:\Projects\HIV_updated\snap_outputs\2021\codons\AF.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\AFG\codons.10444 to G:\Projects\HIV_updated\snap_outputs\2021\codons\AFG.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\AG\codons.5540 to G:\Projects\HIV_updated\snap_outputs\2021\codons\AG.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\AGH\codons.17100 to G:\Projects\HIV_updated\snap_outputs\2021\codons\AGH.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\AH\codons.6360 to G:\Projects\HIV_updated\snap_outputs\2021\codons\AH.txt
# Converted G:\Projects\HIV_updated\snap_outputs\2021\AK\codons.1608 to G:\Projects\HIV_updated\snap_outputs\2021\codons\AK.txt
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [1], in <cell line: 39>()
#      36 output_directory_path = 'G:\\Projects\\HIV_updated\\snap_outputs\\2021\\codons'  # Replace with the actual path to the output directory
#      38 # Call the function to convert the "codon" files to text files
# ---> 39 convert_codon_file_to_text(input_directory_path, output_directory_path)
#
# Input In [1], in convert_codon_file_to_text(input_directory, output_directory)
#      26 # Copy the contents of the "codon" file to the output file
#      27 with open(codon_file_path, "r") as input_file, open(output_file_path, "w") as output_file:
# ---> 28     output_file.write(input_file.read())
#      30 print(f"Converted {codon_file_path} to {output_file_path}")
#
# MemoryError:
